# %% [markdown]
# #  Predicting House Prices by MLR and optimized model  using Backward Elimination annd compare the performance with regulirazation model
#
# Just started with machine learning. I have used backward Elimination to check the usefulness of dependent variables.

# %%
#importing all the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

#importing dataset using panda
dataset = pd.read_csv('/content/House_data (1).csv')
#to see what my dataset is comprised of
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#checking if any value is missing
print(dataset.isnull().any())
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
#checking for categorical data
print(dataset.dtypes)
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#dropping the id and date column
dataset = dataset.drop(['id','date'], axis = 1)

# %%
dataset.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# ## visualization

# %%
# see the distribution of numeric variable by histogram
dataset.hist(bins = 30, figsize = (20,20), color = 'r')
# Out:
# array([[<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>],
#        [<Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>],
#        [<Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>,
#         <Axes: title={'center': 'sqft_basement'}>],
#        [<Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>,
#         <Axes: title={'center': 'sqft_lot15'}>, <Axes: >]], dtype=object)

# %% [markdown]
# insight: from the single variate analysis we can see most of the variable are skewed that have high std dev. lets explore in corelation among them and see how they corelated and how they corelated with price

# %%
corelation = dataset.corr()
f, ax = plt.subplots(figsize = (20,20))
sns.heatmap(corelation,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# from this heatmap we saw some variable intercorelated (Possibility of multicolinearity problem ) and some variable like bathroom, sqft_living, grade, sqft_avobe, lat long highly related with price

# %% [markdown]
# Training the model

# %%
#separating independent and dependent variable
X = dataset.iloc[:,1:].values
y = dataset.iloc[:,0].values
#splitting dataset into training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
print(X_train)
# Out:
# [[ 3.00000e+00  1.50000e+00  1.26000e+03 ... -1.22123e+02  1.80000e+03
#    1.03500e+04]
#  [ 2.00000e+00  1.00000e+00  1.32000e+03 ... -1.22380e+02  1.36000e+03
#    2.87300e+03]
#  [ 3.00000e+00  1.00000e+00  9.20000e+02 ... -1.22269e+02  1.17000e+03
#    9.60000e+03]
#  ...
#  [ 3.00000e+00  2.25000e+00  2.36000e+03 ... -1.22158e+02  2.72000e+03
#    1.43880e+04]
#  [ 4.00000e+00  2.00000e+00  2.37000e+03 ... -1.22279e+02  2.11000e+03
#    1.93340e+04]
#  [ 4.00000e+00  2.25000e+00  2.38000e+03 ... -1.22120e+02  2.23000e+03
#    8.92500e+03]]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [ 386540.99847838 1516969.01534092  538662.72575261 ...  526000.7550575
#   313924.63663324  400525.67314566]

# %%
reg_y_pred_train = regressor.predict(X_train)

# %%
from sklearn.metrics import r2_score

reg_acc_train = r2_score(y_train , reg_y_pred_train)
reg_acc_test = r2_score(y_test , y_pred)

print("Training Accuracy:", round(reg_acc_train, 4))
print("Test Accuracy:", round(reg_acc_test, 4))
# Out:
# Training Accuracy: 0.7061
# Test Accuracy: 0.6856

# %%
# optimize the model with Backward Elimination
import statsmodels.api as sm
import numpy as np

def backwardElimination(x, y, SL):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > SL:
            for j in range(0, numVars - i):
                if regressor_OLS.pvalues[j].astype(float) == maxVar:
                    x = np.delete(x, j, 1)
                    break
    return x, regressor_OLS.summary()

# Assuming you have X and y defined
SL = 0.05
X_opt = X  # Initialize X_opt with all features
X_Modeled, summary = backwardElimination(X_opt, y, SL)

# Print the summary statistics
print(summary)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.905
# Model:                            OLS   Adj. R-squared (uncentered):              0.905
# Method:                 Least Squares   F-statistic:                          1.287e+04
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):                        0.00
# Time:                        12:18:22   Log-Likelihood:                     -2.9461e+05
# No. Observations:               21613   AIC:                                  5.892e+05
# Df Residuals:                   21597   BIC:                                  5.894e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# The warning about the smallest eigenvalue and the mention of potential multicollinearity issues suggest that there might be high collinearity among the independent variables in your model. Multicollinearity can cause numerical instability in estimating the model coefficients and their standard errors

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

def backwardElimination(x, y, feature_names, SL):
    numVars = len(x[0])
    selected_features = list(range(numVars))  # Initialize with all features
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > SL:
            vif = [variance_inflation_factor(x, j) for j in range(x.shape[1])]
            maxVIF = max(vif)
            if maxVIF > 10:  # Adjust the threshold as needed
                remove_index = vif.index(maxVIF)
                x = np.delete(x, remove_index, 1)
                selected_features.pop(remove_index)
                feature_names.pop(remove_index)
            else:
                break
        else:
            break
    return x, feature_names, regressor_OLS.summary()

# Assuming we have X, y, and feature_names defined
SL = 0.05
X_opt = X  # Initialize X_opt with all features
feature_names = list(range(X.shape[1]))  # Assuming X is a NumPy array
X_Modeled, selected_features, summary = backwardElimination(X_opt, y, feature_names, SL)

# Print the selected column names and summary statistics
print("Selected Columns:", selected_features)
print(summary)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/outliers_influence.py:198: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# Selected Columns: [3, 5, 6, 7, 9, 10, 12, 17]
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.860
# Model:                            OLS   Adj. R-squared (uncentered):              0.860
# Method:                 Least Squares   F-statistic:                          1.660e+04
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):                        0.00
# Time:                        12:34:28   Log-Likelihood:                     -2.9880e+05
# No. Observations:               21613   AIC:                                  5.976e+05
# Df Residuals:                   21605   BIC:                                  5.977e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# Conclusion : By backward eleminating we see there are 17 varible that have p values less than 0.05 that have significant affacts in housing price and adjusted R-square is .905,  indicates that the model explains approximately 90% of the variance in the dependent variable, accounting for the number of predictors in the model. After treating the multicollinearity we found adjusted R squre decrease to 0.860 means this model , indicates that the model explains approximately 86% of the variance in the dependent variable, accounting for the number of predictors in the model.
#
# Suggestion : this model may be improve more in further initiative like intercept addition or others model training Let see how lasso and ridge regression

# %% [markdown]
# # Ridge  model compare with regressor

# %%
from sklearn.linear_model import Ridge

rge =Ridge()

rge.fit(X_train , y_train)
# Out:
# Ridge()

# %%
rge.score(X_train , y_train)
# Out:
# 0.706101674006016

# %%
rge.score(X_test , y_test)
# Out:
# 0.6856294081085532

# %%
#regressor
regressor.score(X_train , y_train)
# Out:
# 0.7061048203424924

# %%
regressor.score(X_test , y_test)
# Out:
# 0.685557829548116

# %% [markdown]
# Lasso model

# %%
from sklearn.linear_model import Lasso
lso =Lasso(max_iter=2000)

lso.fit(X_train , y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.508e+14, tolerance: 1.873e+11
#   model = cd_fast.enet_coordinate_descent(
# Lasso(max_iter=2000)

# %%
lso.score(X_train , y_train)
# Out:
# 0.7061048180569509

# %%
lso.score(X_test , y_test)
# Out:
# 0.6855591493985411

# %% [markdown]
# Conclusion: we saw both MLR, and regulirazation model , in both cases we saw R square valu almost similler , In general, it's common for the  test
#   score to be slightly lower on the test set compared to the training set, but the goal is to have a model that generalizes well to new, unseen data. If the drop in performance is substantial, it might indicate issues like overfitting, but inour case slightly lower
